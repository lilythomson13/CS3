# %% [markdown]
# ##Instructions
#
# This code chunk shows the necessary packages to complete a VADER sentiment analysis on the text data. After the dataset has been cleaned and filtered for only US locations, you can use this code as a template to conduct this analysis. After you conduct this analysis, make a new dataframe with the cleaned data and with the appended VADER scores. Continue the analysis as outlined in the rubric document.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Ensure VADER is available
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

# Compute VADER sentiment scores for each tweet
df["VADER Score"] = df["OriginalTweet"].apply(lambda tweet: sia.polarity_scores(str(tweet))["compound"])

# Save the updated dataset with sentiment scores
df.to_csv("df_us_with_sentiment.csv", index=False)
files.download("df_us_with_sentiment.csv")  # Download file

# Display the first few rows of the new dataset
print(df.head())
